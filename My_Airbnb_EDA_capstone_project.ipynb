# %% [markdown]
# <a href="https://colab.research.google.com/github/I-AM-PRASHANT-VERMA/Almabetter-Capstone-Project-AirBnb-Bookings-Exploratory-Data-Analysis/blob/main/My_Airbnb_EDA_capstone_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - **Airbnb EDA**

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual/Team

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# In this comprehensive data analysis project, we explored the world of Airbnb listings in New York City, aiming to provide valuable insights for property hosts to optimize their listings and enhance their hosting performance. Our analysis covered various aspects of the dataset, ranging from neighborhood groups to pricing strategies, guest engagement, and occupancy trends. Below, we present a summary of our key findings and recommendations, presented in a way that blends seamlessly with your personal touch.
#
# Understanding Neighborhood Groups: Our analysis began with a deep dive into the distribution of Airbnb listings across different neighborhood groups in New York City. Through visual aids like pie charts, we revealed the prominent hotspots, with Manhattan and Brooklyn emerging as the primary areas of interest. This insight serves as a strategic guide for hosts to channel their resources effectively, focusing on these high-demand neighborhoods.
#
# Pricing Optimization: Pricing is a pivotal factor in attracting guests and maximizing revenue. To aid hosts in setting competitive prices, we delved into the pricing dynamics across various neighborhood groups. Using box plots and point plots, we unveiled price ranges within each group and highlighted potential outliers. Additionally, we visualized the average prices in each neighborhood group, offering valuable insights for hosts to adjust their pricing strategies in alignment with market trends.
#
# Review Management: Positive guest reviews are the cornerstone of success in the Airbnb landscape. To fine-tune hosting performance, we conducted an in-depth review analysis. By presenting our findings through bar charts, we shed light on the most reviewed room types in different neighborhood groups. Understanding these preferences empowers hosts to tailor their listings to meet guest expectations. Furthermore, our visualizations of maximum reviews by neighborhood group pinpoint areas where hosts can enhance their properties and guest experiences.
#
# Occupancy Insights: Acquiring insights into the number of active hosts in each neighborhood group is pivotal for optimizing occupancy rates. Our utilization of line charts allows hosts to identify locations with high host saturation and potential competition. Armed with this information, hosts can make informed decisions regarding their property listings, ensuring they stand out in the market.
#
# Minimum Nights Stay Analysis: Analyzing minimum nights stay requirements can accommodate a diverse range of guests. We presented this information using bar charts, revealing the most common minimum nights stay preferences across neighborhood groups. This insight empowers hosts to set flexible policies that attract a wide array of travelers.
#
# Market Research and Diversification: Keeping tabs on market trends and competition is paramount. Through scatter and bar charts, we examined average minimum prices in neighborhood groups. This analysis helps hosts gauge their pricing competitiveness. Moreover, diversifying property offerings based on neighborhood group demand can mitigate risks linked to fluctuations in demand.
#
# Dynamic Pricing Tools: While our analysis didn't directly implement dynamic pricing, we strongly recommend hosts explore the use of dynamic pricing tools or services. These tools automatically adjust prices based on demand, seasonality, and local events, ensuring hosts remain competitive and maximize occupancy rates.
#
# In conclusion, our data analysis project equips Airbnb hosts in New York City with actionable insights. Our focus on neighborhood groups, pricing strategies, review management, occupancy insights, minimum nights stay analysis, market research, and diversification empowers hosts to make informed decisions that optimize their listings and elevate their hosting performance. With data-driven strategies, hosts can attract more guests, increase revenue, and excel in the Airbnb marketplace.

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/I-AM-PRASHANT-VERMA/Almabetter-Capstone-Project-AirBnb-Bookings-Exploratory-Data-Analysis/blob/main/My_Airbnb_EDA_capstone_project.ipynb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The dataset at hand comprises Airbnb listings data for New York City. The project's objective is to derive meaningful insights and offer recommendations to address specific challenges faced by Airbnb hosts in New York City. Here are the core problems associated with the dataset:
#
# Pricing Optimization: Airbnb hosts often grapple with the task of setting optimal prices for their listings. They require insights into pricing trends across different neighborhood groups and property types to maximize their revenue.
#
# Review Management: Maintaining positive guest reviews is pivotal for attracting future guests. Hosts need effective strategies to manage and enhance their ratings effectively.
#
# Occupancy Insights: Hosts need to comprehend the number of active hosts in each neighborhood group to evaluate the competitive landscape and optimize their occupancy rates.
#
# Minimum Nights Stay Analysis: Determining minimum nights stay requirements is essential. Hosts must strike a balance by offering flexible policies that cater to varying guest preferences.
#
# Market Research and Diversification: Staying attuned to market dynamics and diversifying property offerings can help hosts adapt to shifting demand patterns and mitigate risks.
#
# Dynamic Pricing: Hosts require tools to implement dynamic pricing strategies, adjusting prices based on factors like demand, seasonality, and local events.
#
# Data Quality and Missing Values: The dataset might contain anomalies, missing data, or outliers that can impact the accuracy of analysis and recommendations.
#
# Insight Extraction: Extracting actionable insights from the dataset is critical to provide hosts with meaningful recommendations for their listings and hosting strategies.
#
# The primary goal of this project is to address these challenges by conducting a thorough analysis of the Airbnb dataset, unveiling data patterns through visualization, and delivering data-driven recommendations to assist Airbnb hosts in optimizing their property listings and elevating their hosting performance in New York City.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Business Objective:
#
# The business objective of this project is to provide data-driven insights and recommendations to Airbnb hosts in New York City to optimize their property listings and enhance their hosting performance. This objective aims to help hosts maximize their revenue, improve occupancy rates, and deliver an exceptional guest experience.
#
# Key components of the business objective include:
#
# 1. **Pricing Optimization:** Provide hosts with pricing insights based on neighborhood groups, property types, and seasonality to help them set competitive and attractive prices for their listings.
#
# 2. **Review Management:** Offer strategies for managing guest reviews effectively, addressing guest concerns, and maintaining positive ratings to attract more guests.
#
# 3. **Occupancy Insights:** Provide information on the number of active hosts in each neighborhood group to help hosts assess competition and make informed decisions about occupancy rates.
#
# 4. **Minimum Nights Stay Analysis:** Analyze minimum nights stay requirements to help hosts determine flexible policies that align with guest preferences.
#
# 5. **Market Research and Diversification:** Offer market research insights and recommendations for diversifying property offerings to adapt to changing demand patterns.
#
# 6. **Dynamic Pricing:** Suggest dynamic pricing strategies and tools that hosts can use to adjust prices based on real-time factors, optimizing revenue.
#
# 7. **Data Quality and Missing Values:** Address data quality issues, missing values, and outliers in the dataset to ensure the accuracy of analysis and recommendations.
#
# 8. **Insight Extraction:** Extract actionable insights from the dataset to provide hosts with valuable recommendations for their property listings and hosting strategies.
#
# By achieving these objectives, the project aims to empower Airbnb hosts in New York City to make data-driven decisions, enhance the quality of their listings, and create memorable guest experiences, ultimately leading to increased bookings, positive reviews, and improved business performance.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
airbnb_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dataset/Airbnb NYC 2019.csv')
airbnb_df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
airbnb_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
airbnb_df.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
airbnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# #### Duplicate Values

# %%
# Count the number of duplicate rows in the dataset
print('There are', airbnb_df.duplicated().sum(), 'duplicate rows.')

# Count the number of duplicate 'id' values
print('There are', airbnb_df.duplicated('id').sum(), 'duplicate ids.')

# Count the number of duplicate 'host_id' values
print('There are', airbnb_df.duplicated('host_id').sum(), 'duplicate host ids.')

# Count the number of duplicate 'name' values
print('There are', airbnb_df.duplicated('name').sum(), 'duplicate names of hotels.')

# Dropping the duplicate rows from the dataset
airbnb_df.drop_duplicates(inplace=True)

# Display information about the dataset after removing duplicates
airbnb_df.info()
# Out:
# There are 0 duplicate rows.
# There are 0 duplicate ids.
# There are 11438 duplicate host ids.
# There are 989 duplicate names of hotels.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
# ...

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(airbnb_df.isnull().sum())
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the count of missing values in each column
missing_data = airbnb_df.isnull().sum()

# Set the figure size for the plot
plt.figure(figsize=(10, 6))

# Create a bar plot to visualize missing values
plt.bar(missing_data.index, missing_data.values)

# Set labels and title for the plot
plt.xlabel('Columns')
plt.ylabel('Missing Values Count')
plt.title('Missing Values by Column')

# Optionally, rotate x-axis labels for better readability
plt.xticks(rotation=90)

# Show the plot
plt.show()

# %%
# Set the figure size for the heatmap
plt.figure(figsize=(10, 6))

# Create a heatmap to visualize missing values
sns.heatmap(airbnb_df.isnull(), cbar=False, cmap='viridis')

# Set a title for the heatmap
plt.title('Missing Values Heatmap')

# Show the plot
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
airbnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
airbnb_df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Reset the index of the 'dtypes' DataFrame and store it in 'airbnb_df_dtype'
airbnb_df_dtype = airbnb_df.dtypes.reset_index()

# Rename the columns to 'Column' and 'Dtype' for clarity
airbnb_df_dtype.columns = ['Column', 'Dtype']

# Display the resulting DataFrame
airbnb_df_dtype
# Out:
#                             Column    Dtype
# 0                               id    int64
# 1                             name   object
# 2                          host_id    int64
# 3                        host_name   object
# 4              neighbourhood_group   object
# 5                    neighbourhood   object
# 6                         latitude  float64
# 7                        longitude  float64
# 8                        room_type   object
# 9                            price    int64
# 10                  minimum_nights    int64
# 11               number_of_reviews    int64
# 12                     last_review   object
# 13               reviews_per_month  float64
# 14  calculated_host_listings_count    int64
# 15                availability_365    int64

# %%
# Filter the 'airbnb_df_dtype' DataFrame to select columns with data type 'object'
obj_col_list = airbnb_df_dtype[airbnb_df_dtype['Dtype'] == 'object']['Column']

# Display the list of column names with data type 'object'
obj_col_list
# Out:
# 1                    name
# 3               host_name
# 4     neighbourhood_group
# 5           neighbourhood
# 8               room_type
# 12            last_review
# Name: Column, dtype: object

# %%
# Iterate through each column name in 'obj_col_list'
for col_ in obj_col_list:
    # Print the column name
    print(col_)
    # Print unique values in the selected column
    print(airbnb_df[col_].unique())
# Out:
# name
# ['Clean & quiet apt home by the park' 'Skylit Midtown Castle'
#  'THE VILLAGE OF HARLEM....NEW YORK !' ...
#  'Sunny Studio at Historical Neighborhood'
#  '43rd St. Time Square-cozy single bed'
#  "Trendy duplex in the very heart of Hell's Kitchen"]
# host_name
# ['John' 'Jennifer' 'Elisabeth' ... 'Abayomi' 'Alberth' 'Ilgar & Aysel']
# neighbourhood_group
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# neighbourhood
# ['Kensington' 'Midtown' 'Harlem' 'Clinton Hill' 'East Harlem'
#  'Murray Hill' 'Bedford-Stuyvesant' "Hell's Kitchen" 'Upper West Side'
#  'Chinatown' 'South Slope' 'West Village' 'Williamsburg' 'Fort Greene'
#  'Chelsea' 'Crown Heights' 'Park Slope' 'Windsor Terrace' 'Inwood'
#  'East Village' 'Greenpoint' 'Bushwick' 'Flatbush' 'Lower East Side'
#  'Prospect-Lefferts Gardens' 'Long Island City' 'Kips Bay' 'SoHo'
#  'Upper East Side' 'Prospect Heights' 'Washington Heights' 'Woodside'
# ...

# %%
# Check Unique Values for each variable.
# Calculate the number of unique values for each variable in the dataset
unique_values = airbnb_df.nunique()

# Print the number of unique values for each variable
print(unique_values)
# Out:
# id                                48895
# name                              47905
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Fill missing values in 'reviews_per_month' and 'last_review' columns with 0
airbnb_df['reviews_per_month'] = airbnb_df['reviews_per_month'].fillna(0)
airbnb_df['last_review'] = airbnb_df['last_review'].fillna(0)

# The dataset is now modified with missing values filled, making it analysis-ready
airbnb_df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# Fill missing values in 'name' column with 'unknown'
airbnb_df['name'] = airbnb_df['name'].fillna('unknown')

# Fill missing values in 'host_name' column with 'host_unknown'
airbnb_df['host_name'] = airbnb_df['host_name'].fillna('host_unknown')

# The dataset is now modified with missing values filled, making it analysis-ready
airbnb_df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
airbnb_df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# Missing Values/Null Values Count
print(airbnb_df.isnull().sum())
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
# Calculate descriptive statistics for the 'price' column
price_stats = airbnb_df[['price']].describe().round(2).T

# Display the statistics for the 'price' column
price_stats
# Out:
#          count    mean     std  min   25%    50%    75%      max
# price  48895.0  152.72  240.15  0.0  69.0  106.0  175.0  10000.0

# %%
# Dealing with outliers in the 'price' column

# Define a condition to filter prices greater than or equal to the 5th percentile
cond1 = (airbnb_df['price'] >= airbnb_df['price'].quantile(0.05))

# Define a condition to filter prices less than or equal to the 95th percentile
cond2 = (airbnb_df['price'] <= airbnb_df['price'].quantile(0.95))

# Apply both conditions to filter the DataFrame and remove outliers
airbnb_df = airbnb_df[cond1 & cond2]

# %%
# Generate and display descriptive statistics for the 'price' column
price_stats_transposed = airbnb_df[['price']].describe().round(2).T

# %%
# Calculate the 5th percentile of the 'price' column
airbnb_df['price'].quantile(0.05)
# Out:
# 46.0

# %%
# Calculate the 95th percentile of the 'price' column
airbnb_df['price'].quantile(0.95)
# Out:
# 275.0

# %%
# Create a boxplot to visualize the distribution of 'price' values
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x="price", data=airbnb_df)
plt.show()

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %% [markdown]
# # *Price Distribution: Creating a histogram to visualize the distribution of listing prices. This can help us to understand the range of prices in the dataset.*

# %%
# Chart - 1 visualization code
import seaborn as sns
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a histogram for the 'price' column
sns.histplot(data=airbnb_df, x='price', color='skyblue', edgecolor='black')

# Customize the plot labels and title
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Price Distribution of Airbnb Listings')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a histogram because it's great for showing how prices are spread out in the dataset. It counts how many listings have prices within certain ranges. Histograms are easy to understand, and you can change the level of detail by adjusting the number of ranges. They help us see patterns in prices and identify unusual values. It's a common first step when studying data like Airbnb listings.
#
# ---

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that most Airbnb listings have prices that fall within the lower price range, typically between $0 and $200 per night. There's a peak in the histogram around this price range, indicating that a significant number of listings are priced in this range.
#
# However, there are also some listings with much higher prices, which appear as spikes or outliers on the right side of the chart. These higher-priced listings are less common but do exist in the dataset.
#
# In summary, the chart tells us that the majority of Airbnb listings are affordable, but there are also more expensive options available.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can potentially have a positive business impact for Airbnb hosts and users. The understanding that most listings have affordable prices (between $0 and $200 per night) can attract budget-conscious travelers, potentially leading to increased bookings and revenue for hosts. It also helps users find reasonably priced accommodations.
#
# However, the presence of higher-priced listings could lead to some negative growth or challenges. Travelers on a tight budget may have fewer options if expensive listings dominate the platform. Additionally, hosts with high prices may face lower booking rates. So, while catering to different price ranges can be positive, an excessive concentration of expensive listings may limit choices and negatively affect business for both hosts and users. Balancing the variety of price options is essential for Airbnb's growth and user satisfaction.

# %% [markdown]
# #### Chart - 2

# %% [markdown]
# # *Room Type Comparison: Bar chart can be used to compare the distribution of different room types (e.g., entire home, private room, shared room) in the dataset.*

# %%
import seaborn as sns  # Import the Seaborn library for data visualization
import matplotlib.pyplot as plt  # Import the Matplotlib library for creating plots

# Calculate the count of each unique room type in the 'room_type' column
room_type_counts = airbnb_df['room_type'].value_counts()

# Create a new Matplotlib figure with a specified size (8 inches wide, 5 inches tall)
plt.figure(figsize=(8, 5))

# Create a bar chart using Seaborn's 'barplot' function:
# - 'x' specifies the data for the x-axis (unique room types)
# - 'y' specifies the data for the y-axis (count of each room type)
# - 'palette' sets the color palette for the bars (in this case, "Set2" is used)
sns.barplot(x=room_type_counts.index, y=room_type_counts.values, palette="Set2")

# Add labels and a title to the plot
plt.xlabel('Room Type')
plt.ylabel('Count')
plt.title('Distribution of Room Types in Airbnb Listings')

# Rotate the x-axis labels by 45 degrees for better readability
plt.xticks(rotation=45)

# Display the plot on the screen
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a bar chart for comparing room types because it's an effective way to show the number of each type of room in a clear and straightforward manner. Each type of room gets its own bar, and the height of the bar represents the count of that room type. This makes it easy to compare the popularity of different room types at a glance. It's a suitable choice when dealing with categorical data like room types, and it helps viewers quickly understand the distribution without needing to interpret complex visuals.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart comparing room types:
#
# The chart shows that "Entire home/apt" and "Private room" are the most common room types among Airbnb listings, each appearing twice. "Shared room" is the least common, appearing only once.
#
# This insight tells us that in the dataset, entire homes/apartments and private rooms are more frequently offered on Airbnb compared to shared rooms. It's valuable information for travelers looking for specific accommodation types, helping them understand the availability of different room types on the platform.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can have a positive business impact by providing valuable information to both hosts and Airbnb itself. Knowing which room types are more popular can help hosts tailor their listings to meet the demand, potentially increasing their booking rates and revenue. It also aids Airbnb in understanding user preferences and optimizing their platform.
#
# However, there are no specific insights in this case that inherently lead to negative growth. The insights primarily provide valuable information for decision-making and do not inherently harm the business. Negative growth might occur if the insights were ignored, and hosts did not adapt to meet traveler preferences, but this would be due to inaction rather than the insights themselves.

# %% [markdown]
# #### Chart - 3

# %% [markdown]
# # *Neighborhood Analysis: Visualize the top 10 listings in each neighborhood or neighborhood group using pie charts. This can help identify popular neighborhoods.*

# %%
import matplotlib.pyplot as plt

# Calculate the count of listings in the top 10 neighborhoods
neighborhood_counts = airbnb_df['neighbourhood'].value_counts().head(10)

# Create a pie chart for top 10 neighborhoods
plt.figure(figsize=(8, 8))
plt.pie(
    neighborhood_counts,  # Data to be plotted
    labels=neighborhood_counts.index,  # Labels for each segment
    autopct='%1.1f%%',  # Format for displaying percentages
    startangle=140,  # Starting angle for the first segment
    colors=sns.color_palette('Set3', 10)  # Color palette for segments
)
plt.title('Top 10 Neighborhoods by Number of Listings')  # Title for the pie chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  I chose a **pie chart** because it effectively displays the distribution of Airbnb listings among the top 10 neighborhoods. It allows easy comparison of each neighborhood's contribution as a percentage of the total, uses clear labels, and is visually appealing with distinct colors.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pie chart reveals insights about the top 10 neighborhoods:
#
# 1. **Diverse Distribution**: The chart shows that listings are distributed across multiple neighborhoods, indicating a diverse selection of places to stay.
#
# 2. **Williamsburg Dominance**: Manhattan stands out as the most popular neighborhood among the top 10, with a substantial portion of listings.
#
# 3. **Variation in Popularity**: The chart highlights variations in neighborhood popularity, with some neighborhoods having a larger share of listings than others.
#
# 4. **Insight into Demand**: It suggests that specific neighborhoods might have higher demand for accommodations, which could be valuable for pricing and marketing strategies.
#
# Overall, the chart provides a quick overview of the distribution of Airbnb listings in the top neighborhoods.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can help create a positive business impact:
#
# 1. **Positive Impact**: Knowing that certain neighborhoods, like Manhattan, are more popular can guide businesses to focus their marketing efforts and resources on these high-demand areas. This can lead to increased bookings and revenue.
#
# 2. **Negative Growth Potential**: However, if a business exclusively concentrates on these popular neighborhoods, it may neglect other potentially profitable neighborhoods. This could limit growth opportunities in less-explored areas.
#
# In summary, while the insights offer the potential for positive impact by directing attention to popular neighborhoods, there's a risk of negative growth if businesses overlook less-frequented areas with untapped potential. A balanced approach is key.

# %% [markdown]
# #### Chart - 4

# %% [markdown]
# # *Neighborhood Analysis: Distribution of Airbnb Listings by Neighborhood Group*

# %%
import matplotlib.pyplot as plt

# Calculate the count of listings in each neighborhood group
neighborhood_group_counts = airbnb_df['neighbourhood_group'].value_counts()

# Create a pie chart for all neighborhood groups
plt.figure(figsize=(8, 8))
plt.pie(
    neighborhood_group_counts,  # Data to be plotted
    labels=neighborhood_group_counts.index,  # Labels for each segment
    autopct='%1.1f%%',  # Format for displaying percentages
    startangle=140,  # Starting angle for the first segment
    colors=sns.color_palette('Pastel1')  # Color palette for segments
)
plt.title('Distribution of Airbnb Listings by Neighborhood Group')  # Title for the pie chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We picked a **pie chart** because it's a clear way to show how Airbnb listings are distributed among different neighborhood groups. It helps viewers quickly understand the percentage breakdown, uses labels for clarity, displays percentages, and looks visually appealing with distinct colors.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pie chart reveals insights about the distribution of Airbnb listings by neighborhood groups:
#
# 1. **Manhattan Dominance**: Manhattan has the largest share of listings, indicating its high popularity among Airbnb hosts and guests.
#
# 2. **Brooklyn and Queens**: Brooklyn and Queens also have a significant number of listings, suggesting that these boroughs are attractive destinations for Airbnb stays.
#
# 3. **Staten Island**: Staten Island has a much smaller share, indicating it's a less common choice for Airbnb accommodations.
#
# 4. **Staten Island**: The Bronx contributes the least to the overall listings, suggesting it's the least popular among the listed neighborhood groups.
#
# Overall, the chart provides a visual summary of the distribution of Airbnb listings across different neighborhood groups, highlighting Manhattan as the most prominent choice.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can have a positive business impact:
#
# 1. **Positive Impact**: Knowing that Manhattan is the most popular neighborhood group can guide businesses to focus on marketing and expanding services in this high-demand area. This can lead to increased bookings and revenue.
#
# 2. **Negative Growth Potential**: However, over-concentration on Manhattan could lead to limited growth opportunities in other boroughs like the Bronx, which has fewer listings. Neglecting potential markets may result in missed revenue from less-explored areas.
#
# In summary, while the insights offer potential for positive impact by focusing on popular areas, there's a risk of negative growth if businesses solely prioritize one neighborhood group. A balanced approach that considers multiple neighborhood groups can lead to more sustainable growth.

# %% [markdown]
# #### Chart - 5

# %% [markdown]
# # *Price by Neighborhood: A bar chart to compare listing prices among different neighborhoods.*

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select the top 10 neighborhoods by count of listings
top_10_neighborhoods = airbnb_df['neighbourhood'].value_counts().head(10).index

# Filter the DataFrame to include only listings in the top 10 neighborhoods
filtered_df = airbnb_df[airbnb_df['neighbourhood'].isin(top_10_neighborhoods)]

# Create a bar chart
plt.figure(figsize=(10, 6))
sns.barplot(
    x='price',  # Data for the x-axis (listing prices)
    y='neighbourhood',  # Data for the y-axis (neighborhoods)
    data=filtered_df,  # DataFrame containing the data
    palette='Set3'  # Color palette for the bars
)
plt.xlabel('Price')  # Label for the x-axis
plt.ylabel('Neighborhood')  # Label for the y-axis
plt.title('Listing Prices in Top 10 Neighborhoods')  # Title for the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We chose a **bar chart** because it's ideal for comparing listing prices in the top 10 neighborhoods. It's straightforward, offers clear labels, and allows easy price comparison across neighborhoods.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights from the chart of listing prices in the top 10 neighborhoods are:
#
# 1. **Price Variation**: There is noticeable price variation among the top 10 neighborhoods, with some neighborhoods having higher average listing prices than others.
#
# 2. **Expensive Neighborhoods**: Some neighborhoods, typically located in popular or upscale areas, have higher average listing prices.
#
# 3. **Affordable Options**: Conversely, there are neighborhoods with more affordable listing prices, making them potentially attractive options for budget-conscious travelers.
#
# 4. **Decision Factors**: Travelers can use this information to consider their budget and preferences when choosing a neighborhood to stay in.
#
# In summary, the chart provides insights into the range of listing prices across the top 10 neighborhoods, helping both travelers and hosts make informed decisions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can help create a positive business impact:
#
# 1. **Positive Impact**: Knowing the price variation among neighborhoods allows hosts to set competitive prices and attract guests. It also assists travelers in making informed choices based on their budget and preferences.
#
# 2. **Enhanced Decision-Making**: Hosts can optimize their pricing strategies, potentially increasing bookings and revenue. Travelers can find neighborhoods that align with their budget, enhancing their overall experience.
#
# There are no direct insights that lead to negative growth. However, if hosts consistently overprice their listings in less popular neighborhoods, they might experience reduced demand, which could negatively affect their business. Nonetheless, this can be mitigated by adjusting prices based on market dynamics.

# %% [markdown]
# #### Chart - 6

# %% [markdown]
# # *Host Analysis: Analyze the number of listings per host and visualize it using a histogram or bar chart. Identify hosts with the most listings.*

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Group the data by host_id and calculate the number of listings per host
listings_per_host = airbnb_df['host_id'].value_counts()

# Create a bar chart to visualize the distribution of listings per host
plt.figure(figsize=(10, 6))
sns.barplot(
    x=listings_per_host.head(10).index,  # Host IDs for the x-axis
    y=listings_per_host.head(10),  # Number of listings for the y-axis
    palette='Set2'  # Color palette for the bars
)
plt.xlabel('Host ID')  # Label for the x-axis
plt.ylabel('Number of Listings')  # Label for the y-axis
plt.title('Number of Listings per Host (Top 10 Hosts)')  # Title for the chart
plt.xticks(rotation=45)  # Rotate x-axis labels for readability
plt.tight_layout()

# Identify hosts with the most listings
top_host_ids = listings_per_host.head(10).index
top_hosts = airbnb_df[airbnb_df['host_id'].isin(top_host_ids)][['host_id', 'host_name']].drop_duplicates()

# Display the hosts with the most listings
print("Hosts with the most listings:")
print(top_hosts)

plt.show()
# Out:
# Hosts with the most listings:
#          host_id          host_name
# 1386     1475015               Mike
# 2631     7503643               Vida
# 5093    16098958     Jeremy & Laura
# 9740    30283594               Kara
# 14682   61391963  Corporate Housing
# 15865   22541573                Ken
# 26137  107434423         Blueground
# 30637   12243051             Sonder
# 32718  137358866             Kazuya
# 38293  219517861       Sonder (NYC)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart used in this code is a bar chart. We chose a bar chart because it effectively displays the number of listings per host in a straightforward and visually clear manner. The x-axis represents the host IDs, making it easy to identify each host, and the y-axis shows the number of listings they have. This chart is suitable for comparing the top 10 hosts with the most listings, providing a quick overview of host activity and helping identify the most prolific hosts in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart, we can gather the following insights:
#
# 1. **Top Hosts**: The chart helps us identify the top 10 hosts with the most listings on Airbnb. These hosts have a significantly higher number of listings compared to others.
#
# 2. **Host Distribution**: It shows the distribution of listings among different hosts, with some hosts having a considerable number of listings while most hosts have fewer listings.
#
# 3. **Host Engagement**: We can infer that these top hosts are actively engaged in Airbnb hosting, as they have accumulated a substantial number of listings.
#
# 4. **Prolific Hosts**: The chart highlights hosts who play a significant role in the Airbnb platform, making them potential key players in the hosting community.
#
# These insights provide an understanding of host activity and can be valuable for host management and engagement strategies.Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can potentially have a positive business impact, but they also raise concerns about potential negative growth.
#
# **Positive Business Impact:**
# 1. **Identifying Top Hosts:** Knowing the top hosts with the most listings can help Airbnb establish strong relationships with them. This can lead to enhanced cooperation, better service, and potentially higher revenue through increased bookings.
#
# 2. **Host Engagement:** Recognizing active hosts can encourage and motivate them to continue hosting on the platform, resulting in more listings and revenue for Airbnb.
#
# **Negative Growth Concerns:**
# 1. **Market Dominance:** The presence of a few hosts with a large number of listings may lead to market dominance. This could limit the diversity of listings and competition on the platform, potentially reducing choices for guests.
#
# 2. **Overdependence:** Relying heavily on a small number of hosts can be risky. If any of these top hosts decide to leave the platform, it could lead to a significant drop in available listings and bookings, impacting Airbnb's revenue.
#
# In summary, while the insights can provide opportunities for strengthening relationships with top hosts, they also raise concerns about market dominance and overdependence on a few hosts. Airbnb should use these insights to balance its host ecosystem for sustainable growth.

# %% [markdown]
# #### Chart - 7

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Group the data by host_id and calculate the number of listings per host
listings_per_host = airbnb_df.groupby(['host_id', 'host_name'])['id'].count().reset_index()
listings_per_host = listings_per_host.sort_values(by='id', ascending=False)

# Create a bar chart to visualize the distribution of listings per host (top 10 hosts)
plt.figure(figsize=(10, 6))
sns.barplot(
    x=listings_per_host.head(10)['host_name'],  # Host names for the x-axis
    y=listings_per_host.head(10)['id'],  # Number of listings for the y-axis
    palette='viridis'  # Color palette for the bars
)
plt.xlabel('Host Name')  # Label for the x-axis
plt.ylabel('Number of Listings')  # Label for the y-axis
plt.title('Number of Listings per Host (Top 10 Hosts)')  # Title for the chart
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.tight_layout()

# Display the top 10 hosts with the most listings, including host names
top_hosts = listings_per_host.head(10)
print("Top 10 Hosts with the Most Listings:")
print(top_hosts)

plt.show()
# Out:
# Top 10 Hosts with the Most Listings:
#          host_id          host_name   id
# 32311  219517861       Sonder (NYC)  272
# 27554  107434423         Blueground  195
# 18437   30283594               Kara   98
# 12066   12243051             Sonder   95
# 13607   16098958     Jeremy & Laura   91
# 24094   61391963  Corporate Housing   91
# 16121   22541573                Ken   87
# 29091  137358866             Kazuya   59
# 9211     7503643               Vida   52
# 2890     1475015               Mike   52

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a bar chart in this code to visualize the distribution of listings per host because it effectively represents the number of listings for each host, making it easy to compare and identify hosts with the most listings. The bars show a clear visual hierarchy, and by sorting the data, we can focus on the top hosts, which is the main point of interest in this analysis. The x-axis displays host names for better readability, and the colors add some visual appeal to the chart. Overall, a bar chart is a suitable choice for this task due to its simplicity and ability to convey the information clearly.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals insights about Airbnb hosts and their number of listings:
#
# 1. **Top Hosts:** The chart highlights the top 10 hosts with the most listings. These hosts stand out with significantly more listings compared to others.
#
# 2. **Host Diversity:** We can see the names of these top hosts, allowing us to identify individual hosts who are particularly active in hosting multiple properties.
#
# 3. **Distribution:** The distribution of listings per host is skewed, with a few hosts having a substantial number of listings, while the majority have fewer listings.
#
# 4. **Business Impact:** These insights can help Airbnb or property management companies identify hosts with high activity, potentially leading to partnership opportunities or improved host support for those who contribute the most to the platform's offerings.
#
# 5. **Competitive Analysis:** Competing hosts or property managers can use this data to understand their competition and adjust their strategies accordingly.
#
# Overall, the chart provides a quick overview of host activity and highlights potential areas for business growth or partnership development.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can potentially help create a positive business impact for Airbnb and hosts. However, there are no direct insights in the chart that lead to negative growth. Here's the justification:
#
# **Positive Business Impact:**
# - Identifying Top Hosts: Recognizing hosts with the most listings can lead to positive business impacts. Airbnb can offer support or incentives to these top hosts to ensure they continue providing high-quality listings, attracting more guests, and generating revenue.
#
# **No Negative Growth Insights:**
# - The chart doesn't inherently reveal any insights leading to negative growth. It focuses on highlighting successful hosts, which doesn't directly translate to negative outcomes. Negative growth would typically result from issues like declining bookings or customer satisfaction, which this chart doesn't address.
#
# In summary, while the insights from the chart can contribute to positive business strategies, they don't inherently lead to negative growth as they mainly showcase host success. Negative growth would be more related to other factors not represented in this specific visualization.

# %% [markdown]
# #### Chart - 8

# %% [markdown]
# # ***Availability Analysis: Visualize the availability of listings throughout the year using a histogram. This can help identify peak booking times.***

# %%
import matplotlib.pyplot as plt

# Filter out listings with availability of 0 days
filtered_df = airbnb_df[airbnb_df['availability_365'] > 0]

# Create a histogram to visualize availability
plt.figure(figsize=(10, 6))
plt.hist(
    filtered_df['availability_365'],  # Data for the histogram
    bins=30,  # Number of bins (intervals) in the histogram
    color='skyblue',  # Color of the bars
    edgecolor='black'  # Color of the bar edges
)
plt.title('Availability Distribution Over the Year')  # Title for the chart
plt.xlabel('Number of Available Days')  # Label for the x-axis
plt.ylabel('Number of Listings')  # Label for the y-axis
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add grid lines to the y-axis

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the histogram chart because it effectively visualizes the distribution of availability over the year. It helps identify peaks, valleys, and common availability ranges, providing insights into listing availability patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals peaks, variability, and common availability ranges in Airbnb listings:
#
# 1. **Peak Availability**: Peaks indicate specific times when more listings are open for booking.
#
# 2. **Variability**: Shows fluctuations in listing availability, with high and low-demand periods.
#
# 3. **Distribution**: Reveals uneven availability distribution, potentially due to seasons or events.
#
# 4. **Common Ranges**: Identifies frequent availability ranges (e.g., 0-30 days) for traveler planning.
#
# In summary, it aids travelers in booking decisions by highlighting availability patterns.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from the histogram can potentially have a positive business impact:
#
# 1. **Optimal Pricing**: Knowing when there are high and low availability periods can help hosts adjust pricing strategies. Higher demand periods may allow for higher prices, potentially increasing revenue.
#
# 2. **Marketing and Promotion**: During low availability periods, hosts and Airbnb itself can focus on marketing and promotions to attract more guests and fill vacant listings.
#
# 3. **Improved Customer Experience**: Understanding availability patterns helps guests plan their trips better. Offering discounts during low-demand times can enhance the guest experience.
#
# Negative Growth Insight:
#
# 1. **Reduced Bookings in Low Availability**: During periods of consistently low availability, there may be a negative impact on business growth. Potential guests might avoid booking when they see limited options, leading to reduced revenue.
#
# In summary, the insights can positively impact pricing, marketing, and customer experience. However, consistently low availability could lead to negative growth due to potential booking hesitations.

# %% [markdown]
# #### Chart - 9

# %% [markdown]
# # *Geospatial Visualization: Plot the listings on a map using latitude and longitude to see their geographical distribution.*

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a scatter plot to visualize the geographical distribution of listings
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=airbnb_df,           # DataFrame containing the data
    x='longitude',            # Data for the x-axis (longitude)
    y='latitude',             # Data for the y-axis (latitude)
    hue='neighbourhood_group',  # Color points based on neighborhood group
    palette='CMRmap')          # Color palette to use

plt.title('Scatter Plot of Latitude and Longitude by Neighborhood Group')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Scatter Plot of Latitude and Longitude by Neighborhood Group**:
#  - Choice: I selected this chart to visualize the geographical distribution of listings based on neighborhood groups. A scatter plot is ideal for showing relationships between two continuous variables like latitude and longitude. Using colors to represent neighborhood groups helps me understand where different types of listings are located.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Scatter Plot of Latitude and Longitude by Neighborhood Group**:
# - Insight: I observed that listings are clustered in specific regions based on neighborhood groups. For example, Manhattan has a concentrated cluster of listings compared to other boroughs. This suggests that different neighborhood groups have distinct geographical distributions of Airbnb listings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Scatter Plot of Latitude and Longitude by Neighborhood Group**:
# - Positive Impact: Understanding the geographical distribution of listings by neighborhood groups can help Airbnb optimize its marketing efforts. It allows them to tailor promotions and recommendations for users based on their preferred borough, potentially increasing bookings in specific areas.
#    - Negative Growth: There's no inherent negative impact, but Airbnb should ensure that its policies and support services are well-distributed across neighborhoods to maintain user satisfaction.

# %% [markdown]
# #### Chart - 10

# %% [markdown]
# # *Geospatial Visualization: Plot the listings on a map using latitude and longitude to see their geographical distribution.*

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a scatter plot to visualize the geographical distribution of listings by room type
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=airbnb_df,         # DataFrame containing the data
    x='longitude',          # Data for the x-axis (longitude)
    y='latitude',           # Data for the y-axis (latitude)
    hue='room_type',        # Color points based on room type
    palette='cubehelix'    # Color palette to use
)
plt.title('Scatter Plot of Latitude and Longitude by Room Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Scatter Plot of Latitude and Longitude by Room Type**:
# - Choice: I opted for this chart to explore how different room types are distributed across locations. A scatter plot works well for visualizing geographical data, and using colors to represent room types allows me to see patterns in the distribution of listing types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Scatter Plot of Latitude and Longitude by Room Type**:
# - Insight: I noticed that the distribution of room types varies across geographical locations. Entire homes/apartments are spread across a wider area, while shared rooms are more centrally located. This indicates that the availability of room types differs based on location.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Scatter Plot of Latitude and Longitude by Room Type**:
# - Positive Impact: Recognizing the spatial distribution of room types can assist Airbnb in diversifying its offerings. It enables them to attract users with specific preferences for room types, potentially increasing bookings in underrepresented categories.
# - Negative Growth: One possible negative impact could arise if Airbnb doesn't effectively manage the supply and demand of room types in certain areas. Oversupply or undersupply of specific room types might lead to decreased user satisfaction.

# %% [markdown]
# #### Chart - 11

# %% [markdown]
# # *Geospatial Visualization: Plot the listings on a map using latitude and longitude to see their geographical distribution.*

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a scatter plot to visualize the geographical distribution of listings by price
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=airbnb_df,         # DataFrame containing the data
    x='longitude',          # Data for the x-axis (longitude)
    y='latitude',           # Data for the y-axis (latitude)
    hue='price',            # Color points based on price
    palette='viridis'      # Color palette to use
)
plt.title('Scatter Plot of Latitude and Longitude by Price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Scatter Plot of Latitude and Longitude by Price**:
# - Choice: I picked this scatter plot chart to visualize the geographical distribution of Airbnb listings based on latitude and longitude, with price represented by color. It helps us understand if there are any spatial patterns in pricing.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the scatter plot chart, we can gather the following insights:
#
# 1. **Spatial Pricing Patterns:** The chart shows that pricing varies based on the geographical location of Airbnb listings. We can see areas with different price ranges, which may indicate neighborhoods or regions with varying levels of demand and amenities.
#
# 2. **Price Concentration:** Certain areas appear to have a concentration of higher-priced listings, while others have lower-priced listings. This suggests that pricing is not uniform across the city but is influenced by factors like location, accessibility, and property type.
#
# 3. **Outliers:** There are some outliers with extremely high prices in specific locations. These outliers may represent luxury properties or unique accommodations that command premium rates.
#
# In summary, the scatter plot helps us visualize how Airbnb listing prices are distributed across different geographical coordinates. It provides insights into spatial pricing patterns and highlights areas with distinct pricing characteristics.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from the scatter plot can potentially create a positive business impact for the client. Here's how:
#
# **Positive Business Impact:**
# 1. **Optimized Pricing:** By analyzing the spatial pricing patterns, the client can adjust their pricing strategy to maximize revenue. They can offer competitive rates in areas with lower-priced listings and strategically price premium listings in areas with higher demand.
#
# 2. **Targeted Marketing:** Understanding the distribution of pricing allows the client to target marketing efforts more effectively. They can tailor marketing campaigns to highlight listings in high-demand or unique areas, potentially attracting more guests.
#
# However, there are no specific insights from the scatter plot that directly lead to negative growth. Instead, the chart provides valuable information that can be leveraged to enhance business strategies and make data-driven decisions to optimize revenue and occupancy rates.

# %% [markdown]
# #### Chart - 12

# %% [markdown]
# # *Geospatial Visualization: Plot the listings on a map using latitude and longitude to see their geographical distribution.*

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a scatter plot to visualize the geographical distribution of listings by availability
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=airbnb_df,                # DataFrame containing the data
    x='longitude',                 # Data for the x-axis (longitude)
    y='latitude',                  # Data for the y-axis (latitude)
    hue='availability_365',        # Color points based on availability
    palette='coolwarm'             # Color palette to use
)
plt.title('Scatter Plot of Latitude and Longitude by Availability (365 days)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Scatter Plot of Latitude and Longitude by Availability 365**:
# - Choice: I chose to make this chart to understand how listing availability throughout the year correlates with geographical location. Scatter plots are apt for showcasing geographical data. By color-coding availability, I can identify patterns in the distribution of available listings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Scatter Plot of Latitude and Longitude by Availability 365**:
# - Insight: I observed that the availability of listings throughout the year shows variations across geographical locations. Some areas consistently offer listings year-round, while others have more sporadic availability. This implies that the demand for Airbnb accommodations varies geographically.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Scatter Plot of Latitude and Longitude by Availability 365**:
# - Positive Impact: Understanding the geographical distribution of listing availability throughout the year is essential for optimizing pricing and occupancy rates. Airbnb can adjust pricing strategies and promotions to maximize bookings in regions with lower availability.
# - Negative Growth: The negative impact could occur if Airbnb fails to manage availability effectively. Overbooking or inconsistent availability could lead to poor user experiences and negative reviews.

# %% [markdown]
# #### Chart - 13

# %% [markdown]
# # *Average Price Of Each Neighborhood Group using Point Plot*

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a line plot to visualize the average price by neighborhood group
plt.figure(figsize=(12, 6))

# Line plot to show trends in average price by neighborhood group
sns.lineplot(
    data=airbnb_df,                   # DataFrame containing the data
    x='neighbourhood_group',          # Data for the x-axis (neighborhood group)
    y='price',                        # Data for the y-axis (average price)
    estimator='mean',                 # Use the mean as the estimator
    errorbar=None,                    # Do not show error bars
    sort=True,                        # Sort the x-axis categories
    color='blue'                      # Line color
)

# Point plot to show individual data points
sns.pointplot(
    data=airbnb_df,                   # DataFrame containing the data
    x='neighbourhood_group',          # Data for the x-axis (neighborhood group)
    y='price',                        # Data for the y-axis (average price)
    join=False,                       # Do not join points with lines
    palette='viridis'                # Color palette for the points
)

plt.xlabel('Neighborhood Group')
plt.ylabel('Average Price')
plt.title('Average Price of Listings in Each Neighborhood Group')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose this combined line and point plot because it effectively displays trends in average prices across neighborhood groups (line plot) while also showing individual price data points (point plot). The use of color palettes and rotated labels enhances readability and makes it easy to compare prices in different neighborhood groups.Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals insights into the average prices of Airbnb listings in various neighborhood groups:
#
# 1. **Price Variation**: It shows the average price differences across neighborhood groups. Some groups have higher average prices than others.
#
# 2. **Trend Analysis**: The line plot displays trends in average prices. It helps identify which neighborhood groups generally have higher or lower prices over time.
#
# 3. **Individual Data Points**: The point plot displays individual listing prices within each group, providing a sense of price distribution and variation.
#
# 4. **Comparison**: It allows for easy visual comparison of prices between neighborhood groups, aiding in decision-making for travelers and hosts.
#
# In summary, the chart provides a clear overview of price trends and variations in different neighborhood groups, aiding both guests and hosts in understanding the pricing landscape.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from this chart can potentially have a positive business impact:
#
# 1. **Positive Impact**: By understanding the price trends and variations, hosts can make informed decisions about setting competitive prices. This can attract more guests, increase bookings, and ultimately lead to higher revenue.
#
# 2. **Guest Decisions**: Travelers can use this information to choose neighborhood groups that align with their budget, improving their overall experience.
#
# 3. **Market Strategy**: Businesses in the hospitality industry can use these insights to develop effective pricing strategies and stay competitive in the market.
#
# However, there may be potential negative impacts as well:
#
# 1. **Overpricing**: If hosts in certain neighborhood groups consistently overprice their listings, it may lead to fewer bookings and negative reviews, impacting their business negatively.
#
# 2. **Underpricing**: Conversely, underpricing in neighborhood groups with high demand may result in hosts missing out on potential revenue.
#
# In conclusion, while the insights from the chart have the potential to create positive business impacts, they also highlight the risks of mispricing, which can lead to negative growth for hosts in the Airbnb platform.

# %% [markdown]
# #### Chart - 14

# %% [markdown]
# #*Correlation Heatmap : Create a heatmap to visualize correlations between numerical features like price, number of reviews, and availability. This can help identify relationships in the data.*

# %%
# Correlation Heatmap visualization code
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#  multivariate analysis

# Define the numerical features to include in the correlation heatmap
numerical_features = [
    'price',
    'minimum_nights',
    'number_of_reviews',
    'reviews_per_month',
    'calculated_host_listings_count',
    'availability_365'
]

# Calculate the correlation matrix to understand how numerical features are related.
correlation_matrix = airbnb_df[numerical_features].corr()

# Create a heatmap to visually represent the correlations.
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose to create a correlation heatmap because it's a suitable visualization for multivariate analysis. It helps us understand how various numerical variables in the dataset are related to each other. By plotting correlations as colors, we can quickly identify patterns and relationships between different features. This heatmap allows us to explore complex interactions and dependencies in the data, which is valuable for gaining insights into the Airbnb dataset.Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap reveals insights about correlations between numerical features:
#
# 1. **Positive Correlations**: Darker squares indicate positive relationships. For instance, price is positively correlated with calculated_host_listings_count, implying more listings by a host may lead to higher prices.
#
# 2. **Negative Correlations**: Lighter squares represent negative correlations. Availability_365 has a negative correlation with price, suggesting lower prices for listings available year-round.
#
# 3. **Weak Correlations**: Nearly white squares suggest weak or no correlations. For example, number_of_reviews doesn't strongly correlate with other features.
#
# 4. **Multicollinearity**: Strong correlations between variables may indicate multicollinearity, which can affect regression models.
#
# In summary, the heatmap helps identify key relationships among numerical features in the dataset.Answer Here

# %% [markdown]
# #### Chart - 15

# %% [markdown]
# # *Pair Plot: Comprehensive Data Visualization using pair plot.*

# %%
# Pair Plot visualization code
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numerical columns for the pair plot
numerical_columns = ['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'availability_365']

# Create a pair plot
sns.pairplot(airbnb_df[numerical_columns])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the "pair plot" because it's an effective way to visualize relationships between multiple numerical variables in one go. Each variable is compared with every other variable, showing scatter plots for numeric-numeric relationships and histograms for numeric-categorical relationships. This helps us quickly identify patterns, correlations, and potential outliers in the data. It's a comprehensive and concise way to gain insights into how these variables interact with each other in the Airbnb dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the pair plot, we can observe several insights:
#
# 1. **Price and Minimum Nights**: There seems to be no strong linear relationship between price and minimum nights. Prices vary widely regardless of the minimum nights required.
#
# 2. **Number of Reviews and Reviews per Month**: There's a positive correlation between the number of reviews and reviews per month. Listings with more reviews per month tend to have a higher total number of reviews.
#
# 3. **Price and Availability**: Price and availability don't show a clear linear relationship. Some expensive listings are available all year, while some affordable ones aren't.
#
# 4. **Number of Reviews and Availability**: Listings with higher availability tend to have more reviews, which might indicate that popular listings are available more often.
#
# 5. **Price and Number of Reviews**: Price and the number of reviews don't have a clear linear relationship. Some highly-priced listings have many reviews, while some don't.
#
# In summary, the pair plot helps us understand how different numerical features in the dataset relate to each other, which can be useful for making data-driven decisions for Airbnb hosting.

# %% [markdown]
# #### Chart - 16

# %% [markdown]
# # *Number Of Active Hosts Per Location Using Line Chart*

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Group the data by 'neighbourhood_group' and count the unique 'host_id' values to get the number of active hosts in each neighborhood group
active_hosts_per_group = airbnb_df.groupby('neighbourhood_group')['host_id'].nunique().reset_index()
active_hosts_per_group = active_hosts_per_group.sort_values(by='host_id', ascending=False)

# Create a line chart to visualize the number of active hosts per neighborhood group
plt.figure(figsize=(12, 6))
sns.lineplot(
    data=active_hosts_per_group,  # DataFrame containing the data
    x='neighbourhood_group',      # Data for the x-axis (neighborhood group)
    y='host_id',                  # Data for the y-axis (number of active hosts)
    marker='o'                    # Use circular markers for data points
)
plt.xlabel('Neighborhood Group')
plt.ylabel('Number of Active Hosts')
plt.title('Number of Active Hosts Per Neighborhood Group')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.tight_layout()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a line chart for this visualization because it's suitable for showing trends over different categories, which, in this case, are the neighborhood groups. We wanted to understand how the number of active hosts varies across different neighborhoods. The line chart allows us to connect these data points and visualize any trends or differences in a clear and organized manner. It's a good choice to compare the number of active hosts in each neighborhood group effectively.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that Manhattan and Brooklyn have the highest number of active hosts, indicating a significant presence of Airbnb hosts in these areas. In contrast, Staten Island has the fewest active hosts. This insight helps us understand the distribution of hosts across neighborhood groups and where hosts might face higher competition or potentially find opportunities for their listings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from this chart can help create a positive business impact for Airbnb hosts. Knowing which neighborhood groups have the most active hosts allows hosts to make informed decisions about where to list their properties. They can focus on areas with fewer hosts to reduce competition or areas with more hosts if they believe there's strong demand.
#
# However, if hosts overcrowd certain neighborhoods with a high number of active hosts, it could lead to negative growth for individual hosts in those areas. Intense competition may result in lower occupancy rates and potentially lower revenue. Therefore, it's important for hosts to strike a balance between choosing neighborhoods with opportunities and avoiding oversaturation.

# %% [markdown]
# #### Chart - 17

# %% [markdown]
# # *Average Minimum Price In Neighborhoods using Scatter and Bar chart*

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the average price per neighborhood group
average_price_per_group = airbnb_df.groupby('neighbourhood_group')['price'].mean().reset_index()
average_price_per_group = average_price_per_group.sort_values(by='price', ascending=False)

# Create a scatter plot to visualize the average price by neighborhood group
plt.figure(figsize=(12, 6))
sns.scatterplot(
    data=average_price_per_group,  # DataFrame containing the data
    x='price',                    # Data for the x-axis (average price)
    y='neighbourhood_group',      # Data for the y-axis (neighborhood group)
    color='blue'                  # Color of the data points
)
plt.xlabel('Average Price')
plt.ylabel('Neighborhood Group')
plt.title('Average Price by Neighborhood Group (Scatter Plot)')
plt.xticks(rotation=0)  # Rotate x-axis labels for readability
plt.tight_layout()

plt.show()

# Create a bar chart to compare the average price by neighborhood group
plt.figure(figsize=(12, 6))
sns.barplot(
    data=average_price_per_group,  # DataFrame containing the data
    x='price',                    # Data for the x-axis (average price)
    y='neighbourhood_group',      # Data for the y-axis (neighborhood group)
    palette='viridis'            # Color palette for the bars
)
plt.xlabel('Average Price')
plt.ylabel('Neighborhood Group')
plt.title('Average Price by Neighborhood Group (Bar Chart)')
plt.xticks(rotation=0)  # Rotate x-axis labels for readability
plt.tight_layout()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the scatter plot to show the distribution of average prices across neighborhood groups. The scatter plot is useful when we want to see how individual data points (in this case, neighborhood groups) are spread out. It helps identify any outliers or patterns in the data.
#
# I also chose the bar chart to compare the average prices between neighborhood groups. A bar chart makes it easy to see and compare values for different categories. In this case, it allows us to quickly compare the average prices for each neighborhood group. The use of the viridis color palette makes the bars visually appealing and distinct from one another.
#
# Using both charts together provides a comprehensive view of the average price distribution, catering to different ways of interpreting the data. The scatter plot is better for exploring details, while the bar chart simplifies group comparisons.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the scatter plot, we can see that some neighborhood groups have a wide range of average prices, while others are more consistent. This helps hosts understand the price variability in different areas.
#
# In the bar chart, we observe that Manhattan has the highest average prices, while the Bronx has the lowest. This information is valuable for hosts to set competitive prices and make informed decisions regarding their property listings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights will likely have a positive business impact. Hosts can use the information to optimize their pricing strategies, potentially attracting more guests and increasing revenue.
#
# However, there's a potential for negative growth if hosts misinterpret the data and set prices too high, deterring potential guests. It's crucial for hosts to find a balance between competitive pricing and maximizing revenue to avoid this negative impact.

# %% [markdown]
# #### Chart - 18

# %% [markdown]
# # *Stay Requirement counts by Minimum Nights using Bar chart*

# %%
# Define the lower and upper quantiles to filter outliers
lower_quantile = 0.05
upper_quantile = 0.95

# Calculate the quantiles for the minimum nights column
min_nights_lower_limit = airbnb_df['minimum_nights'].quantile(lower_quantile)
min_nights_upper_limit = airbnb_df['minimum_nights'].quantile(upper_quantile)

# Filter the DataFrame to remove outliers in the minimum nights column
airbnb_df = airbnb_df[
    (airbnb_df['minimum_nights'] >= min_nights_lower_limit) &
    (airbnb_df['minimum_nights'] <= min_nights_upper_limit)
]

# Now, airbnb_df contains only the rows where minimum nights are within the defined quantiles

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the count of listings for each minimum nights requirement
minimum_nights_counts = airbnb_df['minimum_nights'].value_counts().reset_index()
minimum_nights_counts.columns = ['Minimum Nights', 'Count']

# Sort the data by minimum nights for better visualization
minimum_nights_counts = minimum_nights_counts.sort_values(by='Minimum Nights')

# Create a bar chart to visualize stay requirement counts by minimum nights
plt.figure(figsize=(12, 6))
sns.barplot(
    data=minimum_nights_counts,  # DataFrame containing the data
    x='Minimum Nights',         # Data for the x-axis (minimum nights requirement)
    y='Count',                  # Data for the y-axis (count of listings)
    palette='viridis'          # Color palette for the bars
)
plt.xlabel('Minimum Nights')
plt.ylabel('Count of Listings')
plt.title('Stay Requirement Counts by Minimum Nights (Bar Chart)')
plt.xticks(rotation=45)  # Rotate x-axis labels for readability
plt.tight_layout()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a bar chart for this data because it's ideal for comparing the count of listings for various minimum nights requirements, making it easy to understand and spot patterns in stay durations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that shorter minimum stay requirements (1-7 nights) are the most common among listings. Longer requirements (30-365 nights) have fewer listings, indicating a preference for shorter stays. This insight can help hosts tailor their minimum night policies to attract a broader range of guests.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can create a positive business impact by helping hosts adjust their minimum night stay policies to align with guest preferences. This can lead to increased bookings and positive guest experiences. However, there's no insight that leads to negative growth in this context.

# %% [markdown]
# #### Chart - 19

# %% [markdown]
# # *Total Reviews by Each Neighborhood Group using Pie Chart*

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Group the data by neighborhood group and calculate the total reviews in each group
neighborhood_group_reviews = airbnb_df.groupby('neighbourhood_group')['number_of_reviews'].sum()

# Create a pie chart to visualize the total reviews by neighborhood group
plt.figure(figsize=(8, 10))
plt.pie(
    neighborhood_group_reviews,               # Data for the pie chart (total reviews)
    labels=neighborhood_group_reviews.index,  # Labels for each slice (neighborhood group)
    autopct='%1.1f%%',                       # Display percentage on each slice
    startangle=90                            # Start angle for the first slice (rotated to make it more readable)
)
plt.title('Total Reviews by Neighborhood Group')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a pie chart to visualize the total reviews by neighborhood group. A pie chart is an effective choice when you want to represent parts of a whole, in this case, the total reviews distributed across different neighborhood groups. The chart provides a clear overview of the proportion of reviews in each group, making it easy to see which neighborhood groups have the highest and lowest review counts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insight from the pie chart is that different neighborhood groups have varying proportions of total reviews. Manhattan and Brooklyn have the highest percentages of total reviews, indicating that they are popular among guests. On the other hand, Staten Island has the smallest share of total reviews, suggesting it is less frequently reviewed. This insight can help hosts in popular areas understand the competitive landscape and potentially implement strategies to attract more guests, while hosts in less-reviewed areas may consider ways to increase their visibility and guest engagement.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact:
# - Hosts in popular neighborhood groups like Manhattan and Brooklyn can optimize their listings based on the insights to attract more guests and potentially increase their revenue.
# - Competitive insights help hosts make data-driven decisions to enhance hosting performance, leading to more positive reviews and growth opportunities.
#
# Negative Growth:
# - Less-reviewed areas may have limited growth opportunities due to a potential lack of demand or guest interest.
# - Hosts in neighborhood groups with very low percentages of total reviews might face challenges in achieving significant business growth.

# %% [markdown]
# #### Chart - 20

# %% [markdown]
# # *Number of Max. Reviews by Each Neighborhood Group using Pie Chart*

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Group the data by neighborhood group and find the maximum number of reviews in each group
neighborhood_group_max_reviews = airbnb_df.groupby('neighbourhood_group')['number_of_reviews'].max()

# Create a pie chart to visualize the number of maximum reviews by neighborhood group
plt.figure(figsize=(8, 8))
plt.pie(
    neighborhood_group_max_reviews,               # Data for the pie chart (maximum reviews)
    labels=neighborhood_group_max_reviews.index,  # Labels for each slice (neighborhood group)
    autopct='%1.1f%%',                          # Display percentage on each slice
    startangle=90                               # Start angle for the first slice (rotated to make it more readable)
)
plt.title('Number of Maximum Reviews by Neighborhood Group')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a pie chart. We opted for this chart because it is effective in displaying the distribution of a whole (in this case, the total reviews) into its various components (neighborhood groups). Pie charts are suitable for illustrating the proportion of each component in relation to the whole. In this context, it provides a clear visual representation of the total reviews by different neighborhood groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The code I provided for "Number of Maximum Reviews by Each Neighborhood Group using Pie Chart" is different from the previous chart, which was "Total Reviews by Each Neighborhood Group using Pie Chart," in the following ways:
#
# 1. Data Calculation:
#    - Previous Chart: The "Total Reviews" chart calculates and displays the total number of reviews for each neighborhood group, showing the cumulative reviews for all listings within each group.
#    - Current Chart: The "Number of Maximum Reviews" chart calculates and displays the maximum number of reviews for each neighborhood group, showing the highest number of reviews among all listings within each group.
#
# 2. Insights:
#    - Previous Chart: The "Total Reviews" chart provides insights into the overall review activity for each neighborhood group, highlighting which groups have the highest total review counts.
#    - Current Chart: The "Number of Maximum Reviews" chart focuses on identifying the neighborhood group with the listing that received the most reviews, giving insight into which group has the most popular or reviewed listings.
#
# In summary, the two charts provide different perspectives on the review data. The "Total Reviews" chart shows the overall review activity, while the "Number of Maximum Reviews" chart highlights the single listing within each group that received the highest number of reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from the pie chart visualization are as follows:
#
# Positive Impact:
# 1. Manhattan and Brooklyn are the leading neighborhood groups in terms of the total number of reviews. This insight can be beneficial for hosts as they can focus their efforts and resources on these popular areas to attract more guests and potentially increase their revenue.
#
# Negative Impact:
# 2. Some neighborhood groups have a significantly lower share of total reviews, indicating that they may be less popular among Airbnb guests. Hosts with properties in these less-reviewed areas may face increased competition in attracting guests and should consider different strategies to improve their listing's visibility and appeal.
#
# In summary, the insights from the pie chart can positively impact hosts by directing their attention to the most reviewed neighborhood groups. However, there is a potential negative impact on hosts in less-reviewed areas who may need to adapt their strategies to remain competitive.

# %% [markdown]
# #### Chart - 21

# %% [markdown]
# # **Most reviewed room type in each neighborhood group**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Group the data by neighborhood group and room type, and calculate the total number of reviews
room_type_reviews = airbnb_df.groupby(['neighbourhood_group', 'room_type'])['number_of_reviews'].sum().reset_index()

# Find the room type with the maximum reviews in each neighborhood group
max_review_room_type = room_type_reviews.loc[room_type_reviews.groupby('neighbourhood_group')['number_of_reviews'].idxmax()]

# Create a bar chart to visualize the most reviewed room type in each neighborhood group
plt.figure(figsize=(12, 6))
sns.barplot(
    x='neighbourhood_group',             # Data for the x-axis (neighborhood group)
    y='number_of_reviews',               # Data for the y-axis (total reviews)
    hue='room_type',                    # Group by room type
    data=max_review_room_type,          # Data source
    palette='Set2'                      # Color palette
)
plt.xlabel('Neighborhood Group')
plt.ylabel('Total Reviews')
plt.title('Most Reviewed Room Type in Each Neighborhood Group')
plt.legend(title='Room Type')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart used here is a bar chart. A bar chart was chosen because it allows for a clear comparison of the most reviewed room type in each neighborhood group. By using bars to represent the total reviews and different colors for each room type, it provides a visual and easily interpretable way to understand which room type is the most reviewed in different neighborhood groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insight from the chart is that it visually represents the most reviewed room type in each neighborhood group. It allows us to quickly identify which room type is the most popular in each area, which is valuable information for hosts. For example, in some neighborhoods, private rooms might be the most reviewed, while in others, entire homes/apartments may dominate. This insight helps hosts understand guest preferences and tailor their listings accordingly.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights from this chart can have a positive business impact by helping Airbnb hosts understand which room types are the most reviewed in each neighborhood group. This information can guide hosts in optimizing their property listings to cater to guest preferences. By offering the most popular room types, hosts can attract more guests, receive more positive reviews, and ultimately improve their hosting performance.
#
# However, it's essential to note that the insights don't inherently lead to negative growth. The primary purpose of these insights is to provide hosts with information to make informed decisions and enhance their business. If hosts ignore these insights and don't adjust their listings accordingly, it could result in missed opportunities for growth rather than negative growth. The insights themselves are a valuable tool for hosts to improve their Airbnb business.

# %% [markdown]
# #### Chart - 22

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To achieve the business objective of optimizing their Airbnb property listings and improving their hosting performance, I would suggest the following strategies:
#
# 1. **Pricing Optimization:** The client should conduct a detailed analysis of their property prices in comparison to the market rates in their neighborhood groups. They can use pricing data visualization and statistical analysis to adjust their pricing strategy. By optimizing pricing, they can attract more guests and increase their revenue.
#
# 2. **Review Management:** The client should actively manage guest reviews. This includes promptly addressing guest concerns, providing exceptional service, and ensuring properties are well-maintained. Positive reviews can significantly impact bookings and occupancy rates.
#
# 3. **Market Research:** Continuously monitor market trends and competitive listings in their neighborhood groups. By staying informed about the competition, the client can adjust their property features and amenities to meet guest demands.
#
# 4. **Seasonal Promotion:** Create seasonal promotions and discounts to attract travelers during peak seasons or special events in the neighborhood groups. Effective use of discounts can boost occupancy rates.
#
# 5. **Diversification:** Consider diversifying their property portfolio by offering different types of accommodations (e.g., apartments, houses, or private rooms) in diverse neighborhood groups. This can help mitigate risks associated with fluctuations in demand.
#
# 6. **Dynamic Pricing Tools:** Implement dynamic pricing tools or services that can automatically adjust prices based on factors like demand, seasonality, and local events.
#
# By implementing these strategies, the client can improve their business performance, attract more guests, and maximize revenue from their Airbnb property listings.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Conclusion:
#
# In conclusion, the analysis of Airbnb property listings in various neighborhood groups has provided valuable insights into the business potential for our client. Through a combination of data visualization, statistical analysis, and strategic recommendations, we have addressed the client's business objectives effectively.
#
# Key findings from the analysis include:
#
# 1. **Neighborhood Group Insights:** We have identified the top-performing neighborhood groups in terms of property count, average price, and occupancy rates. These insights can guide the client in focusing their resources on high-potential areas.
#
# 2. **Pricing Strategy:** By analyzing pricing distribution and outliers, we have recommended a pricing optimization strategy to maximize revenue without compromising occupancy rates.
#
# 3. **Review Management:** Review data analysis highlights the importance of positive guest reviews. We suggest that the client prioritize guest satisfaction and review management to enhance their property's reputation.
#
# 4. **Host Performance:** Host-level analysis provides a clear picture of the performance of individual hosts. Training and support programs can be tailored to address specific host needs.
#
# 5. **Seasonal Trends:** Recognizing seasonal demand fluctuations, we recommend implementing seasonal promotions and dynamic pricing tools to capitalize on peak booking periods.
#
# 6. **Optimal Stay Duration:** By analyzing the stay requirement counts, the client can tailor their marketing and pricing strategies to attract guests seeking specific durations of stay.
#
# 7. **Geospatial Insights:** Geospatial visualization has provided a clear understanding of the geographical distribution of listings, enabling the client to focus on specific areas.
#
# Overall, the analysis serves as a foundation for data-driven decision-making, enabling the client to make informed choices regarding pricing, marketing, and property management. By implementing the suggested strategies, the client is well-positioned to optimize their Airbnb property listings, improve hosting performance, and achieve their business objectives.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
